# %% [markdown]
# # Introduction to Neural Networking in Keras

# %% [markdown]
# We will use the version of Keras that comes in the Tensorflow package, as it has the most up to date tools.
#
# Keras works as weapper for deep learning model to be used as classification or regression estimators in sklearn

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from seaborn import heatmap

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, \
classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# new libraries
import tensorflow.keras as keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ### Plot History
#
# Since we will be plotting histories for all of our models, lets create a function to do it quickly.

# %%
def plot_history(history):
  """Takes a keras model learning history and plots each metric"""
  
  metrics = history.history.keys()
  
  for metric in metrics:
      if not 'val' in metric:
        plt.plot(history.history[f'{metric}'], label=f'{metric}')
        if f'val_{metric}' in metrics:
          plt.plot(history.history[f'val_{metric}'], label=f'val_{metric}')
        plt.legend()
        plt.title(f'{metric}')
        plt.show()

# %% [markdown]
# # Data
#
# We will be working with 2 different datasets in this project, 1 is a regression dataset and the other is a classification dataset.  This way you can practice doing both using deep learning.
#
# **NOTE**
#
# These datasets are very small for deep learning.  Deep learning models usually work best with very large datasets with at least 10,000 or more samples.  They work best on even larger datasets than that.  But, for demonstration we will use these smaller datasets.
#
# ## Regression
# This is a dataset of housing prices in Boston from 1978.  Each row is a house and the dataset includes several features regarding each house.  Our target today will be the price of the home.

# %%
regression_df = pd.read_csv('https://raw.githubusercontent.com/ninja-josh/image-storage/main/Boston_Housing_from_Sklearn.csv')

# %% [markdown]
# # Regression
#
# Let's start with modeling the regression dataset

# %%
regression_df
# Out:
#         CRIM    NOX     RM   AGE  PTRATIO  LSTAT  PRICE
# 0    0.00632  0.538  6.575  65.2     15.3   4.98   24.0
# 1    0.02731  0.469  6.421  78.9     17.8   9.14   21.6
# 2    0.02729  0.469  7.185  61.1     17.8   4.03   34.7
# 3    0.03237  0.458  6.998  45.8     18.7   2.94   33.4
# 4    0.06905  0.458  7.147  54.2     18.7   5.33   36.2
# ..       ...    ...    ...   ...      ...    ...    ...
# 501  0.06263  0.573  6.593  69.1     21.0   9.67   22.4
# 502  0.04527  0.573  6.120  76.7     21.0   9.08   20.6
# 503  0.06076  0.573  6.976  91.0     21.0   5.64   23.9
# 504  0.10959  0.573  6.794  89.3     21.0   6.48   22.0
# 505  0.04741  0.573  6.030  80.8     21.0   7.88   11.9
#
# [506 rows x 7 columns]

# %%
regression_df.duplicated().any()
# Out:
# False

# %%
regression_df.describe()
# Out:
#              CRIM         NOX          RM         AGE     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524    0.554695    6.284634   68.574901   18.455534   12.653063
# std      8.601545    0.115878    0.702617   28.148861    2.164946    7.141062
# min      0.006320    0.385000    3.561000    2.900000   12.600000    1.730000
# 25%      0.082045    0.449000    5.885500   45.025000   17.400000    6.950000
# 50%      0.256510    0.538000    6.208500   77.500000   19.050000   11.360000
# 75%      3.677083    0.624000    6.623500   94.075000   20.200000   16.955000
# max     88.976200    0.871000    8.780000  100.000000   22.000000   37.970000
#
#             PRICE
# count  506.000000
# mean    22.532806
# std      9.197104
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %%
# Define X and Y and complete the train test split
X = regression_df.drop(columns = 'PRICE')
y = regression_df['PRICE']

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42)

# %% [markdown]
# ## Scaling
#
# Always scale your data for deep learning.  Otherwise you get a problem call 'Exploding Weights'.  Some weights will be updated much faster than others because the inputs are at larger scales.  This tends to hurt learning as data on smaller scales does not update as fast and doesn't get to contribute as much to the decision making process.  By scaling we put all features on the same footing.

# %%
# Scale the data
scaler = MinMaxScaler()

scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## First Simple Model
#
# We always want to start simple, as deep learning models can get very complex fast and more complex models take more time to train and are more prone to overfitting.  A well performing simple model is better than a well performing complex model.
#
# ## Input layer
# The first layer we will define is not technically the input layer.  We will define the first hidden layer with a special argument that tells Keras how to create a input layer:
#
# `input_dim=`
#
# Input layers can also be defined manually using tensorflow.keras.layers.InputLayer
#
# ## Activation function
#
# For the single hidden layer we will try just 3 nodes and use a ReLU activation.  ReLUs tend to perform well for hidden nodes.
#
# ## Output Layer
#
# For out output layer (last layer) we just use one node because we only want the output of the model to be one number.  We will use a linear activation function.  This will simply output the value from the weights and bias in the node with no change.  The output will be a continuous number, a float.  This will make our model a regression model.

# %%
# Check the shape of input

X_train.shape[1]
# Out:
# 6

# %%
# Instantiate your sequential model

reg_model = Sequential()
# use all features as input using input_dim
input_dim = X_train.shape[1]

# Add first hidden layer
reg_model.add(Dense(10, activation='relu', input_dim=input_dim, name='h1'))
reg_model.add(Dense(10, activation='relu', name='h2'))
# Add output layer with 1 node
reg_model.add(Dense(1, activation='linear', name ='output'))


# Check summary of network 
reg_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  h1 (Dense)                  (None, 10)                90
#
#  h2 (Dense)                  (None, 10)                110
#
#  output (Dense)              (None, 1)                 11
#
# =================================================================
# Total params: 211
# Trainable params: 211
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compiling
#
# Compiling the model puts all the pieces together to make it ready to train.  We need to specify:
#
# * **Optimizer:** An Adam optimizer is a favorite and often performs well, it's a good place to start.
#   - Other optimizers : Gradient Descent,Stochastic Gradient Descent,Adagrad,RMSProp
# * **Loss Function:** 'mse' or mean squared error.  This is the number our model will try to reduce in each epoch.  Since this is a regression model we want our model to minimize the mean squared error.
# * **Metrics:** 'mae' or mean absolute error.  We can provide a list of any appropriate metrics we want the model to keep track at each epoch.

# %%
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
# Compile your model.
rmse = RootMeanSquaredError(name='rmse')

reg_model.compile(optimizer= 'adam', loss = 'mse', metrics= ['mae', rmse])

# %% [markdown]
# # Training
#
# Let's try training our model for 100 few epochs.  Sometimes that is enough, and it will give us an idea whether our model is learning anything.

# %%
# Fit your model

history = reg_model.fit(X_train, y_train,
                        validation_data = (X_test, y_test),
                        epochs = 100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 30ms/step - loss: 0.5398 - mae: 0.5534 - rmse: 0.7347 - val_loss: 0.4479 - val_mae: 0.4671 - val_rmse: 0.6692
# Epoch 2/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4119 - mae: 0.4437 - rmse: 0.6418 - val_loss: 0.3529 - val_mae: 0.3899 - val_rmse: 0.5940
# Epoch 3/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3235 - mae: 0.3692 - rmse: 0.5688 - val_loss: 0.2827 - val_mae: 0.3507 - val_rmse: 0.5317
# Epoch 4/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2633 - mae: 0.3482 - rmse: 0.5131 - val_loss: 0.2327 - val_mae: 0.3550 - val_rmse: 0.4824
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2223 - mae: 0.3640 - rmse: 0.4715 - val_loss: 0.2054 - val_mae: 0.3743 - val_rmse: 0.4532
# Epoch 6/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2010 - mae: 0.3795 - rmse: 0.4483 - val_loss: 0.1945 - val_mae: 0.3857 - val_rmse: 0.4410
# Epoch 7/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1948 - mae: 0.3925 - rmse: 0.4413 - val_loss: 0.1905 - val_mae: 0.3934 - val_rmse: 0.4364
# Epoch 8/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1911 - mae: 0.3972 - rmse: 0.4372 - val_loss: 0.1887 - val_mae: 0.3958 - val_rmse: 0.4344
# Epoch 9/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1885 - mae: 0.3960 - rmse: 0.4341 - val_loss: 0.1870 - val_mae: 0.3926 - val_rmse: 0.4324
# Epoch 10/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1863 - mae: 0.3928 - rmse: 0.4317 - val_loss: 0.1856 - val_mae: 0.3900 - val_rmse: 0.4308
# Epoch 11/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1847 - mae: 0.3878 - rmse: 0.4297 - val_loss: 0.1842 - val_mae: 0.3845 - val_rmse: 0.4292
# Epoch 12/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1828 - mae: 0.3833 - rmse: 0.4276 - val_loss: 0.1831 - val_mae: 0.3820 - val_rmse: 0.4279
# Epoch 13/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1811 - mae: 0.3800 - rmse: 0.4255 - val_loss: 0.1812 - val_mae: 0.3789 - val_rmse: 0.4257
# Epoch 14/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1794 - mae: 0.3781 - rmse: 0.4236 - val_loss: 0.1797 - val_mae: 0.3779 - val_rmse: 0.4239
# Epoch 15/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1777 - mae: 0.3762 - rmse: 0.4216 - val_loss: 0.1786 - val_mae: 0.3756 - val_rmse: 0.4226
# Epoch 16/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1764 - mae: 0.3719 - rmse: 0.4200 - val_loss: 0.1777 - val_mae: 0.3717 - val_rmse: 0.4215
# Epoch 17/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1757 - mae: 0.3712 - rmse: 0.4191 - val_loss: 0.1764 - val_mae: 0.3733 - val_rmse: 0.4200
# Epoch 18/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1748 - mae: 0.3746 - rmse: 0.4181 - val_loss: 0.1765 - val_mae: 0.3770 - val_rmse: 0.4202
# Epoch 19/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1731 - mae: 0.3739 - rmse: 0.4160 - val_loss: 0.1760 - val_mae: 0.3748 - val_rmse: 0.4195
# Epoch 20/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1721 - mae: 0.3691 - rmse: 0.4149 - val_loss: 0.1749 - val_mae: 0.3690 - val_rmse: 0.4183
# Epoch 21/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1705 - mae: 0.3644 - rmse: 0.4130 - val_loss: 0.1741 - val_mae: 0.3671 - val_rmse: 0.4173
# Epoch 22/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1694 - mae: 0.3568 - rmse: 0.4115 - val_loss: 0.1738 - val_mae: 0.3598 - val_rmse: 0.4169
# Epoch 23/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1677 - mae: 0.3513 - rmse: 0.4095 - val_loss: 0.1727 - val_mae: 0.3603 - val_rmse: 0.4156
# Epoch 24/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1658 - mae: 0.3552 - rmse: 0.4072 - val_loss: 0.1727 - val_mae: 0.3659 - val_rmse: 0.4155
# Epoch 25/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1643 - mae: 0.3539 - rmse: 0.4053 - val_loss: 0.1715 - val_mae: 0.3609 - val_rmse: 0.4141
# Epoch 26/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1627 - mae: 0.3492 - rmse: 0.4034 - val_loss: 0.1704 - val_mae: 0.3573 - val_rmse: 0.4128
# Epoch 27/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1616 - mae: 0.3467 - rmse: 0.4020 - val_loss: 0.1696 - val_mae: 0.3562 - val_rmse: 0.4118
# Epoch 28/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1606 - mae: 0.3421 - rmse: 0.4007 - val_loss: 0.1687 - val_mae: 0.3526 - val_rmse: 0.4108
# Epoch 29/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1591 - mae: 0.3403 - rmse: 0.3989 - val_loss: 0.1678 - val_mae: 0.3524 - val_rmse: 0.4096
# Epoch 30/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1578 - mae: 0.3397 - rmse: 0.3973 - val_loss: 0.1670 - val_mae: 0.3507 - val_rmse: 0.4087
# Epoch 31/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1567 - mae: 0.3373 - rmse: 0.3959 - val_loss: 0.1664 - val_mae: 0.3490 - val_rmse: 0.4079
# Epoch 32/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1558 - mae: 0.3339 - rmse: 0.3948 - val_loss: 0.1658 - val_mae: 0.3468 - val_rmse: 0.4071
# Epoch 33/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1550 - mae: 0.3324 - rmse: 0.3937 - val_loss: 0.1653 - val_mae: 0.3463 - val_rmse: 0.4066
# Epoch 34/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1540 - mae: 0.3289 - rmse: 0.3924 - val_loss: 0.1640 - val_mae: 0.3421 - val_rmse: 0.4049
# Epoch 35/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1534 - mae: 0.3285 - rmse: 0.3917 - val_loss: 0.1635 - val_mae: 0.3432 - val_rmse: 0.4043
# Epoch 36/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1524 - mae: 0.3281 - rmse: 0.3904 - val_loss: 0.1632 - val_mae: 0.3423 - val_rmse: 0.4040
# Epoch 37/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1520 - mae: 0.3235 - rmse: 0.3898 - val_loss: 0.1629 - val_mae: 0.3384 - val_rmse: 0.4036
# Epoch 38/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1511 - mae: 0.3224 - rmse: 0.3887 - val_loss: 0.1628 - val_mae: 0.3415 - val_rmse: 0.4035
# Epoch 39/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1502 - mae: 0.3245 - rmse: 0.3875 - val_loss: 0.1626 - val_mae: 0.3420 - val_rmse: 0.4033
# Epoch 40/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1506 - mae: 0.3206 - rmse: 0.3881 - val_loss: 0.1612 - val_mae: 0.3350 - val_rmse: 0.4015
# Epoch 41/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1491 - mae: 0.3199 - rmse: 0.3861 - val_loss: 0.1614 - val_mae: 0.3399 - val_rmse: 0.4018
# Epoch 42/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1479 - mae: 0.3207 - rmse: 0.3846 - val_loss: 0.1610 - val_mae: 0.3393 - val_rmse: 0.4012
# Epoch 43/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1477 - mae: 0.3222 - rmse: 0.3843 - val_loss: 0.1611 - val_mae: 0.3394 - val_rmse: 0.4013
# Epoch 44/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1475 - mae: 0.3180 - rmse: 0.3840 - val_loss: 0.1597 - val_mae: 0.3352 - val_rmse: 0.3996
# Epoch 45/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1466 - mae: 0.3173 - rmse: 0.3828 - val_loss: 0.1605 - val_mae: 0.3367 - val_rmse: 0.4006
# Epoch 46/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1464 - mae: 0.3153 - rmse: 0.3827 - val_loss: 0.1586 - val_mae: 0.3311 - val_rmse: 0.3982
# Epoch 47/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1448 - mae: 0.3135 - rmse: 0.3805 - val_loss: 0.1586 - val_mae: 0.3333 - val_rmse: 0.3983
# Epoch 48/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1445 - mae: 0.3155 - rmse: 0.3801 - val_loss: 0.1589 - val_mae: 0.3340 - val_rmse: 0.3986
# Epoch 49/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1441 - mae: 0.3129 - rmse: 0.3796 - val_loss: 0.1573 - val_mae: 0.3282 - val_rmse: 0.3966
# Epoch 50/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1430 - mae: 0.3099 - rmse: 0.3781 - val_loss: 0.1580 - val_mae: 0.3294 - val_rmse: 0.3974
# Epoch 51/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1426 - mae: 0.3104 - rmse: 0.3776 - val_loss: 0.1571 - val_mae: 0.3277 - val_rmse: 0.3963
# Epoch 52/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1442 - mae: 0.3059 - rmse: 0.3797 - val_loss: 0.1565 - val_mae: 0.3225 - val_rmse: 0.3957
# Epoch 53/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1422 - mae: 0.3058 - rmse: 0.3771 - val_loss: 0.1571 - val_mae: 0.3286 - val_rmse: 0.3964
# Epoch 54/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1410 - mae: 0.3074 - rmse: 0.3755 - val_loss: 0.1569 - val_mae: 0.3278 - val_rmse: 0.3961
# Epoch 55/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1406 - mae: 0.3065 - rmse: 0.3749 - val_loss: 0.1561 - val_mae: 0.3260 - val_rmse: 0.3951
# Epoch 56/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1417 - mae: 0.3044 - rmse: 0.3765 - val_loss: 0.1549 - val_mae: 0.3219 - val_rmse: 0.3936
# Epoch 57/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1396 - mae: 0.3039 - rmse: 0.3737 - val_loss: 0.1562 - val_mae: 0.3258 - val_rmse: 0.3952
# Epoch 58/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1394 - mae: 0.3056 - rmse: 0.3733 - val_loss: 0.1552 - val_mae: 0.3234 - val_rmse: 0.3940
# Epoch 59/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1399 - mae: 0.3009 - rmse: 0.3740 - val_loss: 0.1541 - val_mae: 0.3190 - val_rmse: 0.3925
# Epoch 60/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1388 - mae: 0.3035 - rmse: 0.3726 - val_loss: 0.1565 - val_mae: 0.3257 - val_rmse: 0.3956
# Epoch 61/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1382 - mae: 0.3030 - rmse: 0.3717 - val_loss: 0.1541 - val_mae: 0.3195 - val_rmse: 0.3925
# Epoch 62/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1376 - mae: 0.3002 - rmse: 0.3709 - val_loss: 0.1547 - val_mae: 0.3211 - val_rmse: 0.3933
# Epoch 63/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1374 - mae: 0.3024 - rmse: 0.3707 - val_loss: 0.1560 - val_mae: 0.3237 - val_rmse: 0.3949
# Epoch 64/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1377 - mae: 0.2999 - rmse: 0.3710 - val_loss: 0.1537 - val_mae: 0.3170 - val_rmse: 0.3920
# Epoch 65/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1371 - mae: 0.2984 - rmse: 0.3703 - val_loss: 0.1537 - val_mae: 0.3185 - val_rmse: 0.3920
# Epoch 66/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1367 - mae: 0.2977 - rmse: 0.3698 - val_loss: 0.1533 - val_mae: 0.3169 - val_rmse: 0.3915
# Epoch 67/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1362 - mae: 0.2969 - rmse: 0.3690 - val_loss: 0.1533 - val_mae: 0.3178 - val_rmse: 0.3915
# Epoch 68/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1353 - mae: 0.2979 - rmse: 0.3679 - val_loss: 0.1542 - val_mae: 0.3211 - val_rmse: 0.3927
# Epoch 69/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1347 - mae: 0.2982 - rmse: 0.3670 - val_loss: 0.1538 - val_mae: 0.3198 - val_rmse: 0.3921
# Epoch 70/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1353 - mae: 0.2973 - rmse: 0.3678 - val_loss: 0.1535 - val_mae: 0.3191 - val_rmse: 0.3917
# Epoch 71/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1349 - mae: 0.2967 - rmse: 0.3673 - val_loss: 0.1536 - val_mae: 0.3191 - val_rmse: 0.3920
# Epoch 72/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1336 - mae: 0.2965 - rmse: 0.3655 - val_loss: 0.1547 - val_mae: 0.3214 - val_rmse: 0.3934
# Epoch 73/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1337 - mae: 0.2963 - rmse: 0.3657 - val_loss: 0.1543 - val_mae: 0.3199 - val_rmse: 0.3928
# Epoch 74/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1335 - mae: 0.2975 - rmse: 0.3653 - val_loss: 0.1552 - val_mae: 0.3220 - val_rmse: 0.3940
# Epoch 75/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1334 - mae: 0.2984 - rmse: 0.3653 - val_loss: 0.1551 - val_mae: 0.3214 - val_rmse: 0.3939
# Epoch 76/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1328 - mae: 0.2950 - rmse: 0.3644 - val_loss: 0.1530 - val_mae: 0.3161 - val_rmse: 0.3911
# Epoch 77/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1323 - mae: 0.2937 - rmse: 0.3637 - val_loss: 0.1543 - val_mae: 0.3189 - val_rmse: 0.3929
# Epoch 78/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1322 - mae: 0.2957 - rmse: 0.3636 - val_loss: 0.1547 - val_mae: 0.3190 - val_rmse: 0.3933
# Epoch 79/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1315 - mae: 0.2937 - rmse: 0.3626 - val_loss: 0.1529 - val_mae: 0.3148 - val_rmse: 0.3910
# Epoch 80/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1316 - mae: 0.2904 - rmse: 0.3628 - val_loss: 0.1527 - val_mae: 0.3137 - val_rmse: 0.3908
# Epoch 81/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1313 - mae: 0.2907 - rmse: 0.3623 - val_loss: 0.1532 - val_mae: 0.3159 - val_rmse: 0.3915
# Epoch 82/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1315 - mae: 0.2943 - rmse: 0.3626 - val_loss: 0.1562 - val_mae: 0.3214 - val_rmse: 0.3952
# Epoch 83/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1315 - mae: 0.2964 - rmse: 0.3627 - val_loss: 0.1550 - val_mae: 0.3186 - val_rmse: 0.3937
# Epoch 84/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1303 - mae: 0.2916 - rmse: 0.3609 - val_loss: 0.1525 - val_mae: 0.3131 - val_rmse: 0.3906
# Epoch 85/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1309 - mae: 0.2873 - rmse: 0.3618 - val_loss: 0.1519 - val_mae: 0.3112 - val_rmse: 0.3897
# Epoch 86/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1303 - mae: 0.2911 - rmse: 0.3610 - val_loss: 0.1554 - val_mae: 0.3184 - val_rmse: 0.3942
# Epoch 87/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1310 - mae: 0.2951 - rmse: 0.3619 - val_loss: 0.1551 - val_mae: 0.3176 - val_rmse: 0.3938
# Epoch 88/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1290 - mae: 0.2901 - rmse: 0.3592 - val_loss: 0.1525 - val_mae: 0.3124 - val_rmse: 0.3905
# Epoch 89/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1297 - mae: 0.2879 - rmse: 0.3601 - val_loss: 0.1533 - val_mae: 0.3132 - val_rmse: 0.3916
# Epoch 90/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1288 - mae: 0.2888 - rmse: 0.3589 - val_loss: 0.1548 - val_mae: 0.3157 - val_rmse: 0.3934
# Epoch 91/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1311 - mae: 0.2937 - rmse: 0.3620 - val_loss: 0.1568 - val_mae: 0.3185 - val_rmse: 0.3960
# Epoch 92/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1284 - mae: 0.2888 - rmse: 0.3583 - val_loss: 0.1532 - val_mae: 0.3117 - val_rmse: 0.3914
# Epoch 93/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1282 - mae: 0.2865 - rmse: 0.3580 - val_loss: 0.1528 - val_mae: 0.3112 - val_rmse: 0.3909
# Epoch 94/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1285 - mae: 0.2864 - rmse: 0.3585 - val_loss: 0.1531 - val_mae: 0.3116 - val_rmse: 0.3913
# Epoch 95/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1284 - mae: 0.2874 - rmse: 0.3584 - val_loss: 0.1536 - val_mae: 0.3128 - val_rmse: 0.3919
# Epoch 96/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1282 - mae: 0.2873 - rmse: 0.3581 - val_loss: 0.1530 - val_mae: 0.3118 - val_rmse: 0.3912
# Epoch 97/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1277 - mae: 0.2853 - rmse: 0.3573 - val_loss: 0.1525 - val_mae: 0.3104 - val_rmse: 0.3905
# Epoch 98/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1279 - mae: 0.2852 - rmse: 0.3576 - val_loss: 0.1530 - val_mae: 0.3109 - val_rmse: 0.3911
# Epoch 99/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1275 - mae: 0.2880 - rmse: 0.3571 - val_loss: 0.1557 - val_mae: 0.3161 - val_rmse: 0.3946
# Epoch 100/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1273 - mae: 0.2856 - rmse: 0.3568 - val_loss: 0.1529 - val_mae: 0.3102 - val_rmse: 0.3910

# %%
# Apply the custom function to see how your model is doing
plot_history(history)

# %% [markdown]
# ## Evaluation

# %%
# Make predictions and evaluate your model
train_preds = reg_model.predict(X_train)
test_preds = reg_model.predict(X_test)

print('training MAE:', mean_absolute_error(y_train, train_preds))
print('training rmse:', np.sqrt(mean_squared_error(y_train, train_preds)))
print('training R2:', r2_score(y_train, train_preds))
print('\n')
print('testing MAE:', mean_absolute_error(y_test, test_preds))
print('testing rmse:', np.sqrt(mean_squared_error(y_test, test_preds)))
print('testing R2:', r2_score(y_test, test_preds))
# Out:
# 10/10 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 8ms/step
# training MAE: 0.28343293424315597
# training rmse: 0.35659714586554536
# training R2: 0.42777314002246125
#
#
# testing MAE: 0.3101714475802621
# testing rmse: 0.39098316044088083
# testing R2: 0.30485669691711514

# %% [markdown]
# # <center> Temperature Check: </center>
# ## How confident do you feel in coding neural networks?
# 0. What is a neural net?
# 1. I know what a neural net is, but I wouldn't know how to start coding it.
# 2. I kinda get how the code works, but need help from someone else to create my own.
# 3. I understand the general idea, but would need a full example in front of me.
# 4. I feel confident in coding a neural network with some reference materials.
# 5. Move over, Josh.  I can finish this code-along.

# %% [markdown]
# # Classification:
#
# Classification models are similar, except that we need to adjust:
# * The final activation of the output layer, and
# * the loss function and metrics in the compile step.
#
# We will also need to do some
#
# ### Remember:
# MAE, MSE, RMSE, and R2 are regression metrics,
#
# accuracy, recall, precision, and F1-Score are classification metrics.
#
# ## Classification Dataset
# The classification dataset describes diabetes rates among Pima Indians.  Each row is a person and this dataset includes features regarding health related measurements.  The target is binary and represents whether or not a person will diagnosed with diabetes.  This is another old dataset first presented in 1988.

# %%
classification_df = pd.read_csv('https://raw.githubusercontent.com/ninja-josh/image-storage/main/diabetes.csv')
classification_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
classification_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
classification_df.duplicated().any()
# Out:
# False

# %%
classification_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# We see minimums for Glucose, BloodPression, SkinThickness, Insulin, and BMI of 0s.  Those are impossible for humans, so lets drop those rows.

# %%
no_glucose = classification_df['Glucose'] == 0
no_blood = classification_df['BloodPressure'] == 0
no_skin = classification_df['SkinThickness'] == 0
no_insulin = classification_df['Insulin'] == 0
no_bmi = classification_df['BMI'] == 0

#class_df_clean excludes rows that have no values == 0 in the above columns
class_df_clean = classification_df[~(no_glucose |
                                     no_blood |
                                     no_skin |
                                     no_insulin |
                                     no_bmi)]
class_df_clean.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   392.000000  392.000000     392.000000     392.000000  392.000000
# mean      3.301020  122.627551      70.663265      29.145408  156.056122
# std       3.211424   30.860781      12.496092      10.516424  118.841690
# min       0.000000   56.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      62.000000      21.000000   76.750000
# 50%       2.000000  119.000000      70.000000      29.000000  125.500000
# 75%       5.000000  143.000000      78.000000      37.000000  190.000000
# max      17.000000  198.000000     110.000000      63.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  392.000000                392.000000  392.000000  392.000000
# mean    33.086224                  0.523046   30.864796    0.331633
# std      7.027659                  0.345488   10.200777    0.471401
# min     18.200000                  0.085000   21.000000    0.000000
# 25%     28.400000                  0.269750   23.000000    0.000000
# 50%     33.200000                  0.449500   27.000000    0.000000
# 75%     37.100000                  0.687000   36.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# We lost a lot of data, going from 768 samples to 392 samples.  In the future we might impute this data using means, medians, or other imputation strategies.  For this exercise we won't focus on that.

# %%
# Define X and y and train test split
X = class_df_clean.drop(columns = 'Outcome')
y = class_df_clean['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, stratify = y)

# %%
# Scale the data
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Build the Classification Model
#
# We need to do a few things differently here because this is a binary classification:
#
# 1. The activation of our final layer needs to be 'sigmoid'.
#
#
# (If this were multiclass classification, we would set the final activation as 'softmax' and the number of output nodes would be the number of classes in our y_train.)

# %%
# Build your model

class_model = Sequential()
class_model.add(Dense(10, activation= 'relu', input_dim=X_train.shape[1]))
class_model.add(Dense(5, activation= 'relu'))
class_model.add(Dense(2, activation= 'relu'))

# One output node with 'sigmoid' activation
class_model.add(Dense(1, activation='sigmoid'))
class_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                90
#
#  dense_5 (Dense)             (None, 5)                 55
#
#  dense_6 (Dense)             (None, 2)                 12
#
#  dense_7 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 160
# Trainable params: 160
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## More Changes for Classification:
#
# 1.  We need to change our loss to 'binary_crossentropy'.  If this were multiclass we would use 'categorical_crossentrobpy'.
#
# 2. Our metrics should be classification metrics.  We will use accuracy.  We could also use recall or precision.

# %%
from tensorflow.keras.metrics import Precision, Recall

# %%
# # Compile your model, set metrics = ['acc']
precision = Precision(name='precision')
recall = Recall(name='recall')
class_model.compile(optimizer = 'adam', loss = 'bce', 
                    metrics = ['accuracy', precision, recall])

# %%
# fit your model
history = class_model.fit(X_train, y_train,
                        validation_data = (X_test, y_test),
                        epochs = 300, verbose =0)

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'recall', 'val_loss', 'val_accuracy', 'val_precision', 'val_recall'])

# %%
# See how your model is doing
plot_history(history)

# %% [markdown]
# ## Evaluation
#
# Keras models always output floats, not integers.  In this case the final sigmoid activation function will return a number between 0 and 1.  If the number is closer to 1, the model predicts the sample is more likely to be class 1.  If it is closer to 2, the sample is predicted to be more likely to be class 0.
#
# This is similar to the output of .predict_proba() with Scikit-Learn models.
#
# ### Converting Floats to Ints
#
# In order to use Scikit-Learn metrics functions, the float outputs of the model need to be converted to ints.  We don't want to just use `int(pred)` or `pred.astype(int)` because that will just drop the decimal and all our predictions would be 0s.
#
# Instead we want to **round** the predictions to the nearest integer. To round all of the numbers in an array we can use the NumPy function, `np.rint()` which is short for 'round to integer'.

# %%
# Get predictions and round them to integers instead of floats
train_preds = np.rint(class_model.predict(X_train))
test_preds = np.rint(class_model.predict(X_test))

# the following code should show whole number predictions, 1.0 or 0.0
print(test_preds[:5])
print(train_preds[:5])

# %%
# Define labels for the confusion matrix
labels = ['No Diabetes', 'Diabetes']

# Display train scores
print('Training Scores')

# Classification Report
print(classification_report(y_train, train_preds, zero_division=0))

# Confusion Matrix
ConfusionMatrixDisplay.from_predictions(y_train, train_preds, cmap='Blues',
                                         display_labels=labels)
plt.show()
print('\n')

# Display test scores
print('Testing Scores')

# Classification report
print(classification_report(y_test, test_preds, zero_division=0))

# Confusion Matrix
ConfusionMatrixDisplay.from_predictions(y_test, test_preds, cmap='Blues',
                                         display_labels=labels)
plt.show()
# Out:
# 10/10 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 7ms/step
# Training Scores
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90       196
#            1       0.77      0.87      0.81        98
#
#     accuracy                           0.87       294
#    macro avg       0.85      0.87      0.86       294
# weighted avg       0.87      0.87      0.87       294
# Testing Scores
#               precision    recall  f1-score   support
#
#            0       0.87      0.73      0.79        66
#            1       0.58      0.78      0.67        32
#
#     accuracy                           0.74        98
#    macro avg       0.73      0.75      0.73        98
# weighted avg       0.78      0.74      0.75        98
